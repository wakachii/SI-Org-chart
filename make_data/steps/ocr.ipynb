# %%
import cv2 as cv2
import os
import matplotlib.pyplot as plt
import pyocr
from PIL import Image
from tqdm import tqdm
import re
import numpy as np
path = "/Users/satoshan/Library/CloudStorage/GoogleDrive-sato41kawa0707@gmail.com/マイドライブ/SI-Org-Chart/data/Org_chart/"
# 2002
path_2002_1 = path + "2002/1000-1999"
path_2002_2 = path + "2002/2000-2999"
path_2002_3 = path + "2002/3000-3999"
path_2002_4 = path + "2002/4000-4999"
path_2002_5 = path + "2002/5000-5999"
path_2002_6 = path + "2002/6000-6999"
path_2002_7 = path + "2002/7000-7999"
path_2002_8 = path + "2002/8000-8999"
path_2002_9 = path + "2002/9000-9999"

# 2006
path_2006_1 = path + "2006/1000-1999"
path_2006_2 = path + "2006/2000-2999"
path_2006_3 = path + "2006/3000-3999"
path_2006_4 = path + "2006/4000-4999"
path_2006_5 = path + "2006/5000-5999"
path_2006_6 = path + "2006/6000-6999"
path_2006_7 = path + "2006/7000-7999"
path_2006_8 = path + "2006/8000-8999"
path_2006_9 = path + "2006/9000-9999"

# 2010
path_2010_1 = path + "2010/1000-1999"
path_2010_2 = path + "2010/2000-2999"
path_2010_3 = path + "2010/3000-3999"
path_2010_4 = path + "2010/4000-4999"
path_2010_5 = path + "2010/5000-5999"
path_2010_6 = path + "2010/6000-6999"
path_2010_7 = path + "2010/7000-7999"
path_2010_8 = path + "2010/8000-8999"
path_2010_9 = path + "2010/9000-9999"
metadata = []

# %%
# 2002
## 1000~1999 
print("2002:  1000~1999")
files = os.listdir(path_2002_1)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_1, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_1, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})
                
# 2000~2999
print("2002:  2000~2999")
files = os.listdir(path_2002_2)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_2, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_2, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})

## 3000~3999
print("2002:  3000~3999")
files = os.listdir(path_2002_3)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_3, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_3, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})
## 4000~4999 
print("2002:  4000~4999")
files = os.listdir(path_2002_4)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_4, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_4, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})

# 5000~5999
print("2002:  5000~5999")
files = os.listdir(path_2002_5)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_5, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_5, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})

## 6000~6999
print("2002:  6000~9999")
files = os.listdir(path_2002_6)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_6, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_6, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})
## 7000~7999 
print("2002:  7000~7999")
files = os.listdir(path_2002_7)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_7, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_7, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[100:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})
                
# 8000~8999
print("2002:  8000~8999")
files = os.listdir(path_2002_8)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_8, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_8, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:300, 10:-1450]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})

## 9000~9999
print("2002:  9000~9999")
files = os.listdir(path_2002_9)
files = [f for f in files if os.path.isfile(os.path.join(path_2002_9, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2002_9, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1300]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2002})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2002})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2002})
# Out:
# 2002:  1000~1999
# Processing files: 100%|██████████| 318/318 [00:38<00:00,  8.25it/s]
# 2002:  2000~2999
# Processing files: 100%|██████████| 180/180 [04:59<00:00,  1.66s/it]
# 2002:  3000~3999
# Processing files: 100%|██████████| 138/138 [00:28<00:00,  4.82it/s]
# 2002:  4000~4999
# Processing files: 100%|██████████| 381/381 [01:15<00:00,  5.06it/s]
# 2002:  5000~5999
# Processing files: 100%|██████████| 308/308 [00:58<00:00,  5.25it/s]
# 2002:  6000~9999
# Processing files: 100%|██████████| 538/538 [01:53<00:00,  4.72it/s]
# 2002:  7000~7999
# Processing files: 100%|██████████| 440/440 [01:40<00:00,  4.38it/s]
# 2002:  8000~8999
# Processing files: 100%|██████████| 746/746 [03:19<00:00,  3.73it/s]
# 2002:  9000~9999
# Processing files: 100%|██████████| 530/530 [01:17<00:00,  6.84it/s]

# %%
# 2006
## 1000~1999 
print("2006:  1000~1999")
files = os.listdir(path_2006_1)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_1, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_1, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})
                
# 2000~2999
print("2006:  2000~2999")
files = os.listdir(path_2006_2)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_2, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_2, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})

## 3000~3999
print("2006:  3000~3999")
files = os.listdir(path_2006_3)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_3, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_3, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})
## 4000~4999 
print("2006:  4000~4999")
files = os.listdir(path_2006_4)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_4, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_4, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})

# 5000~5999
print("2006:  5000~5999")
files = os.listdir(path_2006_5)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_5, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_5, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})

## 6000~6999
print("2006:  6000~9999")
files = os.listdir(path_2006_6)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_6, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_6, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})
## 7000~7999 
print("2006:  7000~7999")
files = os.listdir(path_2006_7)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_7, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_7, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})
                
# 8000~8999
print("2006:  8000~8999")
files = os.listdir(path_2006_8)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_8, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_8, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})

## 9000~9999
print("2006:  9000~9999")
files = os.listdir(path_2006_9)
files = [f for f in files if os.path.isfile(os.path.join(path_2006_9, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2006_9, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2006})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2006})
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2006})
# Out:
# 2006:  1000~1999
# Processing files: 100%|██████████| 350/350 [00:40<00:00,  8.57it/s]
# 2006:  2000~2999
# Processing files: 100%|██████████| 481/481 [01:06<00:00,  7.18it/s]
# 2006:  3000~3999
# Processing files: 100%|██████████| 287/287 [00:36<00:00,  7.90it/s]
# 2006:  4000~4999
# Processing files: 100%|██████████| 597/597 [01:13<00:00,  8.14it/s]
# 2006:  5000~5999
# Processing files: 100%|██████████| 336/336 [00:55<00:00,  6.10it/s]
# 2006:  6000~9999
# Processing files: 100%|██████████| 658/658 [01:46<00:00,  6.15it/s]
# 2006:  7000~7999
# Processing files: 100%|██████████| 653/653 [01:36<00:00,  6.77it/s]
# 2006:  8000~8999
# Processing files: 100%|██████████| 793/793 [02:27<00:00,  5.39it/s]
# 2006:  9000~9999
# Processing files: 100%|██████████| 692/692 [02:03<00:00,  5.60it/s]

# %%
# 2010
## 1000~1999 
print("2010:  1000~1999")
files = os.listdir(path_2010_1)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_1, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_1, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('1')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  
                
# 2000~2999
print("2010:  2000~2999")
files = os.listdir(path_2010_2)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_2, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_2, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('2')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  

## 3000~3999
print("2010:  3000~3999")
files = os.listdir(path_2010_3)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_3, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_3, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('3')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  
## 4000~4999 
print("2010:  4000~4999")
files = os.listdir(path_2010_4)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_4, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_4, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('4')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  

# 5000~5999
print("2010:  5000~5999")
files = os.listdir(path_2010_5)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_5, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_5, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('5')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  

## 6000~6999
print("2010:  6000~6999")
files = os.listdir(path_2010_6)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_6, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_6, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('6')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  
## 7000~7999 
print("2010:  7000~7999")
files = os.listdir(path_2010_7)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_7, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_7, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="eng",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('7')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  
                
# 8000~8999
print("2010:  8000~8999")
files = os.listdir(path_2010_8)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_8, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_8, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('8')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})  

## 9000~9999
print("2010:  9000~9999")
files = os.listdir(path_2010_9)
files = [f for f in files if os.path.isfile(os.path.join(path_2010_9, f))]
files.sort()
for i in tqdm(range(len(files)), desc="Processing files"):
    # load image
    file = os.path.join(path_2010_9, files[i])
    img = cv2.imread(file)
    # preprocessing for OCR
    header = img[0:200, 10:-1350]
    gray_image = cv2.cvtColor(header, cv2.COLOR_BGR2GRAY)
    gray_image_inv = cv2.bitwise_not(gray_image)
    pil_image = Image.fromarray(gray_image)
    tools = pyocr.get_available_tools()
    tool = tools[0]
    txt = tool.image_to_string(
        pil_image,
        lang="jpn",
        builder=pyocr.builders.TextBuilder(tesseract_layout=6)
    )
    filtered_text = re.findall(r'\d+', txt)
    if len(filtered_text) >= 1:
        if (len(filtered_text[0]) == 4 and filtered_text[0].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[0],"year": 2010})
    elif len(filtered_text) >= 2:
        if (len(filtered_text[1]) == 4 and filtered_text[1].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[1],"year": 2010})  
    elif len(filtered_text) >= 3:
        if (len(filtered_text[2]) == 4 and filtered_text[2].startswith('9')):
                metadata.append({"fig_path": file,"code": filtered_text[2],"year": 2010})
# Out:
# 2010:  1000~1999
# Processing files: 100%|██████████| 276/276 [00:41<00:00,  6.63it/s]
# 2010:  2000~2999
# Processing files: 100%|██████████| 523/523 [01:38<00:00,  5.31it/s]
# 2010:  3000~3999
# Processing files: 100%|██████████| 470/470 [01:47<00:00,  4.37it/s]
# 2010:  4000~4999
# Processing files: 100%|██████████| 535/535 [02:30<00:00,  3.55it/s]
# 2010:  5000~5999
# Processing files: 100%|██████████| 325/325 [01:17<00:00,  4.18it/s]
# 2010:  6000~9999
# Processing files: 100%|██████████| 673/673 [01:57<00:00,  5.74it/s]
# 2010:  7000~7999
# Processing files: 100%|██████████| 661/661 [01:27<00:00,  7.55it/s]
# 2010:  8000~8999
# Processing files: 100%|██████████| 686/686 [01:36<00:00,  7.11it/s]
# 2010:  9000~9999
# Processing files: 100%|██████████| 604/604 [01:31<00:00,  6.61it/s]

# %%
import json

json_data = json.dumps(metadata, ensure_ascii=False, indent=4)
print(json_data)

save_path = path + 'file_code_year.json'
with open(save_path, 'w', encoding='utf-8') as f:
    json.dump(metadata, f, ensure_ascii=False, indent=4)
# Out:
# [
#     {
#         "fig_path": "/Users/satoshan/Library/CloudStorage/GoogleDrive-sato41kawa0707@gmail.com/マイドライブ/SI-Org-Chart/data/Org_chart/2002/1000-1999/IMG_2025_02_26_14_16_43_289R.jpg",
#         "code": "1301",
#         "year": 2002
#     },
#     {
#         "fig_path": "/Users/satoshan/Library/CloudStorage/GoogleDrive-sato41kawa0707@gmail.com/マイドライブ/SI-Org-Chart/data/Org_chart/2002/1000-1999/IMG_2025_02_26_14_16_55_973L.jpg",
#         "code": "1331",
#         "year": 2002
#     },
#     {
#         "fig_path": "/Users/satoshan/Library/CloudStorage/GoogleDrive-sato41kawa0707@gmail.com/マイドライブ/SI-Org-Chart/data/Org_chart/2002/1000-1999/IMG_2025_02_26_14_17_22_823L.jpg",
#         "code": "1333",
#         "year": 2002
#     },
#     {
#         "fig_path": "/Users/satoshan/Library/CloudStorage/GoogleDrive-sato41kawa0707@gmail.com/マイドライブ/SI-Org-Chart/data/Org_chart/2002/1000-1999/IMG_2025_02_26_14_17_27_444R.jpg",
#         "code": "1351",
#         "year": 2002
# ...
